# %%
# Measure some strings:
words = ['cat', 'window', 'defenestrate']
for w in words:
    print(w, len(w))
# Out:
# cat 3
# window 6
# defenestrate 12

# %% [markdown]
# The range() Function

# %%
users={'Hans':'active','Elenore':'inactive','Ram':'active'}
for user,status in users.copy().items():
    print(f"name:{user} status:{status}")
# Out:
# name:hans status:active
# name:Elenore status:inactive
# name:Ram status:active

# %% [markdown]
# # Strategy:  Create a new collection

# %%
active_users={}
for user,status in users.items():
    if status=='active':
        active_users[user] = status;

print(active_users)
# Out:
# {'hans': 'active', 'Ram': 'active'}

# %% [markdown]
# Range with step

# %%
a=list(range(0, 10, 3))
for i in range(len(a)):
    print(i, a[i])
for it in a:
    print(it)    
print(a)
# Out:
# 0 0
# 1 3
# 2 6
# 3 9
# 0
# 3
# 6
# 9
# [0, 3, 6, 9]

# %% [markdown]
# 4.7. match Statements

# %%
def http_error(status):
    match status:
        case 400:
            return "Bad request"
        case 404:
            return "Not found"
        case 418:
            return "I'm a teapot"
        case _:
            return "Something's wrong with the internet"
st=http_error(404);
print(f"status:{st}")
# Out:
# status:Not found
